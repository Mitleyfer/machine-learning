# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
import torch.nn.functional as F
from torch import nn
from torch import optim
from torchvision import datasets, models, transforms
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
random_transforms = [transforms.RandomAffine(30), transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip()]
train_transforms = transforms.Compose([transforms.RandomRotation(45),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomChoice(random_transforms),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir, transform = train_transforms)
valid_dataset = datasets.ImageFolder(valid_dir, transform = data_transforms)
test_dataset = datasets.ImageFolder(test_dir, transform = data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
classifier = nn.Sequential(OrderedDict([('inp', nn.Linear(512,256)),
                                       ('dropout', nn.Dropout(p=0.4)),
                                       ('relu', nn.ReLU()),
                                       ('out', nn.Linear(256,102)),
                                       ('softmax', nn.LogSoftmax(dim=1))]))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=True)

for i in model.parameters():
    i.requires_grad = False
    
model.fc = classifier
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr = 0.002)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 100%|██████████| 46827520/46827520 [00:03<00:00, 12989645.35it/s]

# %%
model.to(device)
epochs = 3
steps = 0
running_loss = 0
printing = 10
i = 0
control_dict = {}

for epoch in range(epochs):
    for inputs, labels in trainloader:
        optimizer.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device)
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss+=loss.item()
        i+=1
        if steps%printing == 0:
            valid_loss = 0
            accuracy = 0
            model.eval()
            
            for inputs1, labels1 in validloader:
                optimizer.zero_grad()
                inputs1, labels1 = inputs1.to(device), labels1.to(device)
                model.to(device)
                with torch.no_grad():
                    logps = model.forward(inputs1)
                    batch_loss = criterion(logps, labels1)
                    valid_loss += batch_loss.item()
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equality = top_class == labels1.view(*top_class.shape)
                    accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
                    
            control_dict[i] = [running_loss/printing, valid_loss/len(validloader), accuracy/len(validloader)]
        
            print(f"{i}) Epoch {epoch+1}/{epochs}.. "
                f"Train loss: {running_loss/printing:.3f}.. "
                f"Test loss: {valid_loss/len(validloader):.3f}.. "
                f"Test accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# 1) Epoch 1/3.. Train loss: 0.471.. Test loss: 4.653.. Test accuracy: 0.013
# 2) Epoch 1/3.. Train loss: 0.475.. Test loss: 4.634.. Test accuracy: 0.009
# 3) Epoch 1/3.. Train loss: 0.461.. Test loss: 4.618.. Test accuracy: 0.023
# 4) Epoch 1/3.. Train loss: 0.475.. Test loss: 4.585.. Test accuracy: 0.029
# 5) Epoch 1/3.. Train loss: 0.452.. Test loss: 4.554.. Test accuracy: 0.026
# 6) Epoch 1/3.. Train loss: 0.460.. Test loss: 4.507.. Test accuracy: 0.040
# 7) Epoch 1/3.. Train loss: 0.464.. Test loss: 4.465.. Test accuracy: 0.063
# 8) Epoch 1/3.. Train loss: 0.474.. Test loss: 4.421.. Test accuracy: 0.062
# 9) Epoch 1/3.. Train loss: 0.447.. Test loss: 4.392.. Test accuracy: 0.069
# 10) Epoch 1/3.. Train loss: 0.443.. Test loss: 4.364.. Test accuracy: 0.084
# 11) Epoch 1/3.. Train loss: 0.440.. Test loss: 4.337.. Test accuracy: 0.070
# 12) Epoch 1/3.. Train loss: 0.437.. Test loss: 4.325.. Test accuracy: 0.054
# 13) Epoch 1/3.. Train loss: 0.448.. Test loss: 4.306.. Test accuracy: 0.071
# 14) Epoch 1/3.. Train loss: 0.439.. Test loss: 4.280.. Test accuracy: 0.111
# 15) Epoch 1/3.. Train loss: 0.429.. Test loss: 4.261.. Test accuracy: 0.130
# 16) Epoch 1/3.. Train loss: 0.450.. Test loss: 4.237.. Test accuracy: 0.143
# 17) Epoch 1/3.. Train loss: 0.441.. Test loss: 4.210.. Test accuracy: 0.133
# 18) Epoch 1/3.. Train loss: 0.446.. Test loss: 4.188.. Test accuracy: 0.133
# 19) Epoch 1/3.. Train loss: 0.446.. Test loss: 4.164.. Test accuracy: 0.139
# 20) Epoch 1/3.. Train loss: 0.425.. Test loss: 4.143.. Test accuracy: 0.138
# 21) Epoch 1/3.. Train loss: 0.422.. Test loss: 4.126.. Test accuracy: 0.131
# 22) Epoch 1/3.. Train loss: 0.429.. Test loss: 4.107.. Test accuracy: 0.121
# 23) Epoch 1/3.. Train loss: 0.428.. Test loss: 4.081.. Test accuracy: 0.119
# 24) Epoch 1/3.. Train loss: 0.405.. Test loss: 4.059.. Test accuracy: 0.116
# 25) Epoch 1/3.. Train loss: 0.415.. Test loss: 4.035.. Test accuracy: 0.119
# 26) Epoch 1/3.. Train loss: 0.425.. Test loss: 4.010.. Test accuracy: 0.122
# 27) Epoch 1/3.. Train loss: 0.422.. Test loss: 3.982.. Test accuracy: 0.120
# 28) Epoch 1/3.. Train loss: 0.412.. Test loss: 3.961.. Test accuracy: 0.122
# 29) Epoch 1/3.. Train loss: 0.429.. Test loss: 3.939.. Test accuracy: 0.130
# 30) Epoch 1/3.. Train loss: 0.418.. Test loss: 3.915.. Test accuracy: 0.148
# 31) Epoch 1/3.. Train loss: 0.411.. Test loss: 3.875.. Test accuracy: 0.166
# 32) Epoch 1/3.. Train loss: 0.428.. Test loss: 3.831.. Test accuracy: 0.203
# 33) Epoch 1/3.. Train loss: 0.417.. Test loss: 3.787.. Test accuracy: 0.206
# 34) Epoch 1/3.. Train loss: 0.390.. Test loss: 3.757.. Test accuracy: 0.191
# 35) Epoch 1/3.. Train loss: 0.404.. Test loss: 3.735.. Test accuracy: 0.182
# 36) Epoch 1/3.. Train loss: 0.383.. Test loss: 3.704.. Test accuracy: 0.181
# 37) Epoch 1/3.. Train loss: 0.403.. Test loss: 3.682.. Test accuracy: 0.193
# 38) Epoch 1/3.. Train loss: 0.410.. Test loss: 3.656.. Test accuracy: 0.202
# 39) Epoch 1/3.. Train loss: 0.375.. Test loss: 3.636.. Test accuracy: 0.201
# 40) Epoch 1/3.. Train loss: 0.379.. Test loss: 3.610.. Test accuracy: 0.211
# 41) Epoch 1/3.. Train loss: 0.408.. Test loss: 3.582.. Test accuracy: 0.214
# 42) Epoch 1/3.. Train loss: 0.415.. Test loss: 3.562.. Test accuracy: 0.218
# 43) Epoch 1/3.. Train loss: 0.390.. Test loss: 3.528.. Test accuracy: 0.218
# 44) Epoch 1/3.. Train loss: 0.382.. Test loss: 3.493.. Test accuracy: 0.213
# 45) Epoch 1/3.. Train loss: 0.395.. Test loss: 3.457.. Test accuracy: 0.233
# 46) Epoch 1/3.. Train loss: 0.369.. Test loss: 3.407.. Test accuracy: 0.254
# 47) Epoch 1/3.. Train loss: 0.342.. Test loss: 3.365.. Test accuracy: 0.255
# 48) Epoch 1/3.. Train loss: 0.369.. Test loss: 3.338.. Test accuracy: 0.244
# 49) Epoch 1/3.. Train loss: 0.363.. Test loss: 3.303.. Test accuracy: 0.238
# 50) Epoch 1/3.. Train loss: 0.389.. Test loss: 3.268.. Test accuracy: 0.259
# 51) Epoch 1/3.. Train loss: 0.355.. Test loss: 3.229.. Test accuracy: 0.277
# 52) Epoch 1/3.. Train loss: 0.345.. Test loss: 3.189.. Test accuracy: 0.292
# 53) Epoch 1/3.. Train loss: 0.373.. Test loss: 3.154.. Test accuracy: 0.319
# 54) Epoch 1/3.. Train loss: 0.311.. Test loss: 3.124.. Test accuracy: 0.322
# 55) Epoch 1/3.. Train loss: 0.348.. Test loss: 3.094.. Test accuracy: 0.320
# 56) Epoch 1/3.. Train loss: 0.323.. Test loss: 3.066.. Test accuracy: 0.312
# 57) Epoch 1/3.. Train loss: 0.359.. Test loss: 3.039.. Test accuracy: 0.320
# 58) Epoch 1/3.. Train loss: 0.326.. Test loss: 3.023.. Test accuracy: 0.302
# 59) Epoch 1/3.. Train loss: 0.356.. Test loss: 2.988.. Test accuracy: 0.302
# 60) Epoch 1/3.. Train loss: 0.327.. Test loss: 2.942.. Test accuracy: 0.316
# 61) Epoch 1/3.. Train loss: 0.339.. Test loss: 2.887.. Test accuracy: 0.345
# 62) Epoch 1/3.. Train loss: 0.330.. Test loss: 2.844.. Test accuracy: 0.354
# 63) Epoch 1/3.. Train loss: 0.314.. Test loss: 2.823.. Test accuracy: 0.353
# 64) Epoch 1/3.. Train loss: 0.342.. Test loss: 2.811.. Test accuracy: 0.357
# 65) Epoch 1/3.. Train loss: 0.334.. Test loss: 2.793.. Test accuracy: 0.362
# 66) Epoch 1/3.. Train loss: 0.313.. Test loss: 2.775.. Test accuracy: 0.369
# 67) Epoch 1/3.. Train loss: 0.318.. Test loss: 2.764.. Test accuracy: 0.371
# 68) Epoch 1/3.. Train loss: 0.363.. Test loss: 2.757.. Test accuracy: 0.376
# 69) Epoch 1/3.. Train loss: 0.331.. Test loss: 2.736.. Test accuracy: 0.396
# 70) Epoch 1/3.. Train loss: 0.329.. Test loss: 2.720.. Test accuracy: 0.406
# 71) Epoch 1/3.. Train loss: 0.309.. Test loss: 2.699.. Test accuracy: 0.409
# 72) Epoch 1/3.. Train loss: 0.320.. Test loss: 2.680.. Test accuracy: 0.411
# 73) Epoch 1/3.. Train loss: 0.305.. Test loss: 2.670.. Test accuracy: 0.415
# 74) Epoch 1/3.. Train loss: 0.313.. Test loss: 2.655.. Test accuracy: 0.414
# 75) Epoch 1/3.. Train loss: 0.310.. Test loss: 2.633.. Test accuracy: 0.420
# 76) Epoch 1/3.. Train loss: 0.285.. Test loss: 2.611.. Test accuracy: 0.413
# 77) Epoch 1/3.. Train loss: 0.307.. Test loss: 2.585.. Test accuracy: 0.403
# 78) Epoch 1/3.. Train loss: 0.307.. Test loss: 2.555.. Test accuracy: 0.409
# 79) Epoch 1/3.. Train loss: 0.298.. Test loss: 2.531.. Test accuracy: 0.406
# 80) Epoch 1/3.. Train loss: 0.320.. Test loss: 2.503.. Test accuracy: 0.399
# 81) Epoch 1/3.. Train loss: 0.301.. Test loss: 2.474.. Test accuracy: 0.398
# 82) Epoch 1/3.. Train loss: 0.308.. Test loss: 2.429.. Test accuracy: 0.428
# 83) Epoch 1/3.. Train loss: 0.306.. Test loss: 2.373.. Test accuracy: 0.455
# 84) Epoch 1/3.. Train loss: 0.288.. Test loss: 2.321.. Test accuracy: 0.476
# 85) Epoch 1/3.. Train loss: 0.314.. Test loss: 2.274.. Test accuracy: 0.483
# 86) Epoch 1/3.. Train loss: 0.290.. Test loss: 2.259.. Test accuracy: 0.487
# 87) Epoch 1/3.. Train loss: 0.275.. Test loss: 2.243.. Test accuracy: 0.492
# 88) Epoch 1/3.. Train loss: 0.300.. Test loss: 2.245.. Test accuracy: 0.499
# 89) Epoch 1/3.. Train loss: 0.290.. Test loss: 2.256.. Test accuracy: 0.493
# 90) Epoch 1/3.. Train loss: 0.243.. Test loss: 2.260.. Test accuracy: 0.481
# 91) Epoch 1/3.. Train loss: 0.274.. Test loss: 2.258.. Test accuracy: 0.469
# 92) Epoch 1/3.. Train loss: 0.322.. Test loss: 2.241.. Test accuracy: 0.475
# 93) Epoch 1/3.. Train loss: 0.296.. Test loss: 2.218.. Test accuracy: 0.476
# 94) Epoch 1/3.. Train loss: 0.266.. Test loss: 2.183.. Test accuracy: 0.484
# 95) Epoch 1/3.. Train loss: 0.268.. Test loss: 2.154.. Test accuracy: 0.505
# 96) Epoch 1/3.. Train loss: 0.284.. Test loss: 2.141.. Test accuracy: 0.524
# 97) Epoch 1/3.. Train loss: 0.287.. Test loss: 2.127.. Test accuracy: 0.537
# 98) Epoch 1/3.. Train loss: 0.307.. Test loss: 2.108.. Test accuracy: 0.561
# 99) Epoch 1/3.. Train loss: 0.257.. Test loss: 2.091.. Test accuracy: 0.556
# 100) Epoch 1/3.. Train loss: 0.279.. Test loss: 2.074.. Test accuracy: 0.543
# 101) Epoch 1/3.. Train loss: 0.255.. Test loss: 2.067.. Test accuracy: 0.534
# 102) Epoch 1/3.. Train loss: 0.248.. Test loss: 2.072.. Test accuracy: 0.502
# 103) Epoch 1/3.. Train loss: 0.261.. Test loss: 2.060.. Test accuracy: 0.496
# 104) Epoch 2/3.. Train loss: 0.262.. Test loss: 2.036.. Test accuracy: 0.503
# 105) Epoch 2/3.. Train loss: 0.287.. Test loss: 2.016.. Test accuracy: 0.516
# 106) Epoch 2/3.. Train loss: 0.249.. Test loss: 1.992.. Test accuracy: 0.543
# 107) Epoch 2/3.. Train loss: 0.264.. Test loss: 1.978.. Test accuracy: 0.550
# 108) Epoch 2/3.. Train loss: 0.225.. Test loss: 1.977.. Test accuracy: 0.548
# 109) Epoch 2/3.. Train loss: 0.258.. Test loss: 1.965.. Test accuracy: 0.550
# 110) Epoch 2/3.. Train loss: 0.275.. Test loss: 1.934.. Test accuracy: 0.564
# 111) Epoch 2/3.. Train loss: 0.267.. Test loss: 1.894.. Test accuracy: 0.576
# 112) Epoch 2/3.. Train loss: 0.247.. Test loss: 1.861.. Test accuracy: 0.594
# 113) Epoch 2/3.. Train loss: 0.238.. Test loss: 1.828.. Test accuracy: 0.594
# 114) Epoch 2/3.. Train loss: 0.256.. Test loss: 1.807.. Test accuracy: 0.595
# 115) Epoch 2/3.. Train loss: 0.260.. Test loss: 1.797.. Test accuracy: 0.609
# 116) Epoch 2/3.. Train loss: 0.286.. Test loss: 1.810.. Test accuracy: 0.612
# 117) Epoch 2/3.. Train loss: 0.261.. Test loss: 1.811.. Test accuracy: 0.603
# 118) Epoch 2/3.. Train loss: 0.249.. Test loss: 1.798.. Test accuracy: 0.600
# 119) Epoch 2/3.. Train loss: 0.250.. Test loss: 1.788.. Test accuracy: 0.601
# 120) Epoch 2/3.. Train loss: 0.257.. Test loss: 1.778.. Test accuracy: 0.594
# 121) Epoch 2/3.. Train loss: 0.225.. Test loss: 1.767.. Test accuracy: 0.604
# 122) Epoch 2/3.. Train loss: 0.201.. Test loss: 1.755.. Test accuracy: 0.603
# 123) Epoch 2/3.. Train loss: 0.254.. Test loss: 1.747.. Test accuracy: 0.606
# 124) Epoch 2/3.. Train loss: 0.245.. Test loss: 1.733.. Test accuracy: 0.607
# 125) Epoch 2/3.. Train loss: 0.238.. Test loss: 1.732.. Test accuracy: 0.616
# 126) Epoch 2/3.. Train loss: 0.220.. Test loss: 1.715.. Test accuracy: 0.613
# 127) Epoch 2/3.. Train loss: 0.208.. Test loss: 1.705.. Test accuracy: 0.617
# 128) Epoch 2/3.. Train loss: 0.261.. Test loss: 1.679.. Test accuracy: 0.608
# 129) Epoch 2/3.. Train loss: 0.239.. Test loss: 1.656.. Test accuracy: 0.616
# 130) Epoch 2/3.. Train loss: 0.248.. Test loss: 1.627.. Test accuracy: 0.633
# 131) Epoch 2/3.. Train loss: 0.214.. Test loss: 1.613.. Test accuracy: 0.633
# 132) Epoch 2/3.. Train loss: 0.236.. Test loss: 1.588.. Test accuracy: 0.644
# 133) Epoch 2/3.. Train loss: 0.224.. Test loss: 1.552.. Test accuracy: 0.648
# 134) Epoch 2/3.. Train loss: 0.221.. Test loss: 1.531.. Test accuracy: 0.657
# 135) Epoch 2/3.. Train loss: 0.188.. Test loss: 1.510.. Test accuracy: 0.677
# 136) Epoch 2/3.. Train loss: 0.234.. Test loss: 1.503.. Test accuracy: 0.676
# 137) Epoch 2/3.. Train loss: 0.229.. Test loss: 1.514.. Test accuracy: 0.665
# 138) Epoch 2/3.. Train loss: 0.220.. Test loss: 1.534.. Test accuracy: 0.659
# 139) Epoch 2/3.. Train loss: 0.293.. Test loss: 1.554.. Test accuracy: 0.639
# 140) Epoch 2/3.. Train loss: 0.270.. Test loss: 1.529.. Test accuracy: 0.651
# 141) Epoch 2/3.. Train loss: 0.240.. Test loss: 1.508.. Test accuracy: 0.645
# 142) Epoch 2/3.. Train loss: 0.248.. Test loss: 1.503.. Test accuracy: 0.640
# 143) Epoch 2/3.. Train loss: 0.210.. Test loss: 1.515.. Test accuracy: 0.638
# 144) Epoch 2/3.. Train loss: 0.166.. Test loss: 1.522.. Test accuracy: 0.634
# 145) Epoch 2/3.. Train loss: 0.242.. Test loss: 1.522.. Test accuracy: 0.624
# 146) Epoch 2/3.. Train loss: 0.218.. Test loss: 1.521.. Test accuracy: 0.619
# 147) Epoch 2/3.. Train loss: 0.253.. Test loss: 1.510.. Test accuracy: 0.623
# 148) Epoch 2/3.. Train loss: 0.216.. Test loss: 1.486.. Test accuracy: 0.637
# 149) Epoch 2/3.. Train loss: 0.222.. Test loss: 1.471.. Test accuracy: 0.633
# 150) Epoch 2/3.. Train loss: 0.217.. Test loss: 1.481.. Test accuracy: 0.635
# 151) Epoch 2/3.. Train loss: 0.252.. Test loss: 1.475.. Test accuracy: 0.646
# 152) Epoch 2/3.. Train loss: 0.250.. Test loss: 1.470.. Test accuracy: 0.653
# 153) Epoch 2/3.. Train loss: 0.216.. Test loss: 1.472.. Test accuracy: 0.656
# 154) Epoch 2/3.. Train loss: 0.220.. Test loss: 1.475.. Test accuracy: 0.664
# 155) Epoch 2/3.. Train loss: 0.199.. Test loss: 1.478.. Test accuracy: 0.660
# 156) Epoch 2/3.. Train loss: 0.261.. Test loss: 1.483.. Test accuracy: 0.649
# 157) Epoch 2/3.. Train loss: 0.200.. Test loss: 1.463.. Test accuracy: 0.656
# 158) Epoch 2/3.. Train loss: 0.216.. Test loss: 1.447.. Test accuracy: 0.653
# 159) Epoch 2/3.. Train loss: 0.219.. Test loss: 1.432.. Test accuracy: 0.649
# 160) Epoch 2/3.. Train loss: 0.204.. Test loss: 1.424.. Test accuracy: 0.644
# 161) Epoch 2/3.. Train loss: 0.244.. Test loss: 1.418.. Test accuracy: 0.638
# 162) Epoch 2/3.. Train loss: 0.230.. Test loss: 1.414.. Test accuracy: 0.642
# 163) Epoch 2/3.. Train loss: 0.232.. Test loss: 1.399.. Test accuracy: 0.646
# 164) Epoch 2/3.. Train loss: 0.216.. Test loss: 1.389.. Test accuracy: 0.657
# 165) Epoch 2/3.. Train loss: 0.203.. Test loss: 1.386.. Test accuracy: 0.648
# 166) Epoch 2/3.. Train loss: 0.200.. Test loss: 1.381.. Test accuracy: 0.644
# 167) Epoch 2/3.. Train loss: 0.243.. Test loss: 1.370.. Test accuracy: 0.662
# 168) Epoch 2/3.. Train loss: 0.203.. Test loss: 1.353.. Test accuracy: 0.674
# 169) Epoch 2/3.. Train loss: 0.201.. Test loss: 1.337.. Test accuracy: 0.683
# 170) Epoch 2/3.. Train loss: 0.180.. Test loss: 1.321.. Test accuracy: 0.689
# 171) Epoch 2/3.. Train loss: 0.178.. Test loss: 1.308.. Test accuracy: 0.694
# 172) Epoch 2/3.. Train loss: 0.213.. Test loss: 1.299.. Test accuracy: 0.700
# 173) Epoch 2/3.. Train loss: 0.211.. Test loss: 1.287.. Test accuracy: 0.710
# 174) Epoch 2/3.. Train loss: 0.219.. Test loss: 1.270.. Test accuracy: 0.712
# 175) Epoch 2/3.. Train loss: 0.211.. Test loss: 1.264.. Test accuracy: 0.716
# 176) Epoch 2/3.. Train loss: 0.209.. Test loss: 1.251.. Test accuracy: 0.714
# 177) Epoch 2/3.. Train loss: 0.225.. Test loss: 1.231.. Test accuracy: 0.722
# 178) Epoch 2/3.. Train loss: 0.206.. Test loss: 1.210.. Test accuracy: 0.735
# 179) Epoch 2/3.. Train loss: 0.235.. Test loss: 1.199.. Test accuracy: 0.733
# 180) Epoch 2/3.. Train loss: 0.195.. Test loss: 1.204.. Test accuracy: 0.722
# 181) Epoch 2/3.. Train loss: 0.214.. Test loss: 1.216.. Test accuracy: 0.717
# 182) Epoch 2/3.. Train loss: 0.183.. Test loss: 1.229.. Test accuracy: 0.703
# 183) Epoch 2/3.. Train loss: 0.189.. Test loss: 1.246.. Test accuracy: 0.689
# 184) Epoch 2/3.. Train loss: 0.188.. Test loss: 1.264.. Test accuracy: 0.679
# 185) Epoch 2/3.. Train loss: 0.185.. Test loss: 1.267.. Test accuracy: 0.676
# 186) Epoch 2/3.. Train loss: 0.197.. Test loss: 1.268.. Test accuracy: 0.685
# 187) Epoch 2/3.. Train loss: 0.198.. Test loss: 1.251.. Test accuracy: 0.700
# 188) Epoch 2/3.. Train loss: 0.203.. Test loss: 1.236.. Test accuracy: 0.707
# 189) Epoch 2/3.. Train loss: 0.211.. Test loss: 1.220.. Test accuracy: 0.708
# 190) Epoch 2/3.. Train loss: 0.215.. Test loss: 1.189.. Test accuracy: 0.721
# 191) Epoch 2/3.. Train loss: 0.153.. Test loss: 1.165.. Test accuracy: 0.736
# 192) Epoch 2/3.. Train loss: 0.193.. Test loss: 1.147.. Test accuracy: 0.737
# 193) Epoch 2/3.. Train loss: 0.173.. Test loss: 1.140.. Test accuracy: 0.753
# 194) Epoch 2/3.. Train loss: 0.204.. Test loss: 1.134.. Test accuracy: 0.751
# 195) Epoch 2/3.. Train loss: 0.197.. Test loss: 1.127.. Test accuracy: 0.746
# 196) Epoch 2/3.. Train loss: 0.189.. Test loss: 1.124.. Test accuracy: 0.749
# 197) Epoch 2/3.. Train loss: 0.213.. Test loss: 1.123.. Test accuracy: 0.752
# 198) Epoch 2/3.. Train loss: 0.227.. Test loss: 1.114.. Test accuracy: 0.761
# 199) Epoch 2/3.. Train loss: 0.187.. Test loss: 1.117.. Test accuracy: 0.755
# 200) Epoch 2/3.. Train loss: 0.197.. Test loss: 1.124.. Test accuracy: 0.745
# 201) Epoch 2/3.. Train loss: 0.223.. Test loss: 1.140.. Test accuracy: 0.731
# 202) Epoch 2/3.. Train loss: 0.193.. Test loss: 1.145.. Test accuracy: 0.725
# 203) Epoch 2/3.. Train loss: 0.230.. Test loss: 1.158.. Test accuracy: 0.724
# 204) Epoch 2/3.. Train loss: 0.205.. Test loss: 1.163.. Test accuracy: 0.722
# 205) Epoch 2/3.. Train loss: 0.177.. Test loss: 1.179.. Test accuracy: 0.713
# 206) Epoch 2/3.. Train loss: 0.236.. Test loss: 1.180.. Test accuracy: 0.716
# 207) Epoch 3/3.. Train loss: 0.178.. Test loss: 1.187.. Test accuracy: 0.704
# 208) Epoch 3/3.. Train loss: 0.186.. Test loss: 1.186.. Test accuracy: 0.702
# 209) Epoch 3/3.. Train loss: 0.192.. Test loss: 1.182.. Test accuracy: 0.697
# 210) Epoch 3/3.. Train loss: 0.192.. Test loss: 1.174.. Test accuracy: 0.687
# 211) Epoch 3/3.. Train loss: 0.187.. Test loss: 1.157.. Test accuracy: 0.696
# 212) Epoch 3/3.. Train loss: 0.190.. Test loss: 1.141.. Test accuracy: 0.703
# 213) Epoch 3/3.. Train loss: 0.165.. Test loss: 1.135.. Test accuracy: 0.705
# 214) Epoch 3/3.. Train loss: 0.191.. Test loss: 1.121.. Test accuracy: 0.707
# 215) Epoch 3/3.. Train loss: 0.172.. Test loss: 1.105.. Test accuracy: 0.711
# 216) Epoch 3/3.. Train loss: 0.207.. Test loss: 1.078.. Test accuracy: 0.730
# 217) Epoch 3/3.. Train loss: 0.191.. Test loss: 1.064.. Test accuracy: 0.743
# 218) Epoch 3/3.. Train loss: 0.158.. Test loss: 1.061.. Test accuracy: 0.752
# 219) Epoch 3/3.. Train loss: 0.170.. Test loss: 1.070.. Test accuracy: 0.725
# 220) Epoch 3/3.. Train loss: 0.163.. Test loss: 1.097.. Test accuracy: 0.719
# 221) Epoch 3/3.. Train loss: 0.188.. Test loss: 1.107.. Test accuracy: 0.707
# 222) Epoch 3/3.. Train loss: 0.194.. Test loss: 1.124.. Test accuracy: 0.695
# 223) Epoch 3/3.. Train loss: 0.183.. Test loss: 1.124.. Test accuracy: 0.687
# 224) Epoch 3/3.. Train loss: 0.197.. Test loss: 1.112.. Test accuracy: 0.695
# 225) Epoch 3/3.. Train loss: 0.157.. Test loss: 1.086.. Test accuracy: 0.714
# 226) Epoch 3/3.. Train loss: 0.183.. Test loss: 1.049.. Test accuracy: 0.736
# 227) Epoch 3/3.. Train loss: 0.177.. Test loss: 1.037.. Test accuracy: 0.743
# 228) Epoch 3/3.. Train loss: 0.207.. Test loss: 1.022.. Test accuracy: 0.747
# 229) Epoch 3/3.. Train loss: 0.156.. Test loss: 1.027.. Test accuracy: 0.740
# 230) Epoch 3/3.. Train loss: 0.170.. Test loss: 1.029.. Test accuracy: 0.740
# 231) Epoch 3/3.. Train loss: 0.209.. Test loss: 1.027.. Test accuracy: 0.746
# 232) Epoch 3/3.. Train loss: 0.184.. Test loss: 1.014.. Test accuracy: 0.764
# 233) Epoch 3/3.. Train loss: 0.187.. Test loss: 0.997.. Test accuracy: 0.768
# 234) Epoch 3/3.. Train loss: 0.221.. Test loss: 0.994.. Test accuracy: 0.778
# 235) Epoch 3/3.. Train loss: 0.188.. Test loss: 1.007.. Test accuracy: 0.766
# 236) Epoch 3/3.. Train loss: 0.199.. Test loss: 1.018.. Test accuracy: 0.762
# 237) Epoch 3/3.. Train loss: 0.190.. Test loss: 1.035.. Test accuracy: 0.746
# 238) Epoch 3/3.. Train loss: 0.172.. Test loss: 1.046.. Test accuracy: 0.741
# 239) Epoch 3/3.. Train loss: 0.205.. Test loss: 1.052.. Test accuracy: 0.746
# 240) Epoch 3/3.. Train loss: 0.179.. Test loss: 1.062.. Test accuracy: 0.741
# 241) Epoch 3/3.. Train loss: 0.210.. Test loss: 1.063.. Test accuracy: 0.743
# 242) Epoch 3/3.. Train loss: 0.209.. Test loss: 1.062.. Test accuracy: 0.742
# 243) Epoch 3/3.. Train loss: 0.192.. Test loss: 1.063.. Test accuracy: 0.737
# 244) Epoch 3/3.. Train loss: 0.168.. Test loss: 1.055.. Test accuracy: 0.737
# 245) Epoch 3/3.. Train loss: 0.189.. Test loss: 1.041.. Test accuracy: 0.749
# 246) Epoch 3/3.. Train loss: 0.185.. Test loss: 1.025.. Test accuracy: 0.756
# 247) Epoch 3/3.. Train loss: 0.210.. Test loss: 1.023.. Test accuracy: 0.766
# 248) Epoch 3/3.. Train loss: 0.193.. Test loss: 1.031.. Test accuracy: 0.751
# 249) Epoch 3/3.. Train loss: 0.201.. Test loss: 1.036.. Test accuracy: 0.734
# 250) Epoch 3/3.. Train loss: 0.166.. Test loss: 1.035.. Test accuracy: 0.736
# 251) Epoch 3/3.. Train loss: 0.210.. Test loss: 1.030.. Test accuracy: 0.747
# 252) Epoch 3/3.. Train loss: 0.179.. Test loss: 1.024.. Test accuracy: 0.753
# 253) Epoch 3/3.. Train loss: 0.148.. Test loss: 1.019.. Test accuracy: 0.755
# 254) Epoch 3/3.. Train loss: 0.137.. Test loss: 1.009.. Test accuracy: 0.758
# 255) Epoch 3/3.. Train loss: 0.215.. Test loss: 1.004.. Test accuracy: 0.765
# 256) Epoch 3/3.. Train loss: 0.176.. Test loss: 0.983.. Test accuracy: 0.773
# 257) Epoch 3/3.. Train loss: 0.182.. Test loss: 0.973.. Test accuracy: 0.782
# 258) Epoch 3/3.. Train loss: 0.173.. Test loss: 0.958.. Test accuracy: 0.790
# 259) Epoch 3/3.. Train loss: 0.186.. Test loss: 0.945.. Test accuracy: 0.786
# 260) Epoch 3/3.. Train loss: 0.197.. Test loss: 0.953.. Test accuracy: 0.789
# 261) Epoch 3/3.. Train loss: 0.156.. Test loss: 0.968.. Test accuracy: 0.781
# 262) Epoch 3/3.. Train loss: 0.191.. Test loss: 0.984.. Test accuracy: 0.773
# 263) Epoch 3/3.. Train loss: 0.190.. Test loss: 0.987.. Test accuracy: 0.768
# 264) Epoch 3/3.. Train loss: 0.179.. Test loss: 0.979.. Test accuracy: 0.764
# 265) Epoch 3/3.. Train loss: 0.197.. Test loss: 0.981.. Test accuracy: 0.760
# 266) Epoch 3/3.. Train loss: 0.162.. Test loss: 0.974.. Test accuracy: 0.767
# 267) Epoch 3/3.. Train loss: 0.213.. Test loss: 0.955.. Test accuracy: 0.775
# 268) Epoch 3/3.. Train loss: 0.194.. Test loss: 0.945.. Test accuracy: 0.772
# 269) Epoch 3/3.. Train loss: 0.199.. Test loss: 0.939.. Test accuracy: 0.778
# 270) Epoch 3/3.. Train loss: 0.169.. Test loss: 0.933.. Test accuracy: 0.788
# 271) Epoch 3/3.. Train loss: 0.207.. Test loss: 0.937.. Test accuracy: 0.777
# 272) Epoch 3/3.. Train loss: 0.217.. Test loss: 0.934.. Test accuracy: 0.779
# 273) Epoch 3/3.. Train loss: 0.180.. Test loss: 0.929.. Test accuracy: 0.785
# 274) Epoch 3/3.. Train loss: 0.152.. Test loss: 0.910.. Test accuracy: 0.795
# 275) Epoch 3/3.. Train loss: 0.224.. Test loss: 0.890.. Test accuracy: 0.801
# 276) Epoch 3/3.. Train loss: 0.177.. Test loss: 0.887.. Test accuracy: 0.804
# 277) Epoch 3/3.. Train loss: 0.183.. Test loss: 0.888.. Test accuracy: 0.806
# 278) Epoch 3/3.. Train loss: 0.165.. Test loss: 0.900.. Test accuracy: 0.802
# 279) Epoch 3/3.. Train loss: 0.148.. Test loss: 0.914.. Test accuracy: 0.793
# 280) Epoch 3/3.. Train loss: 0.185.. Test loss: 0.925.. Test accuracy: 0.793
# 281) Epoch 3/3.. Train loss: 0.201.. Test loss: 0.925.. Test accuracy: 0.805
# 282) Epoch 3/3.. Train loss: 0.176.. Test loss: 0.913.. Test accuracy: 0.802
# 283) Epoch 3/3.. Train loss: 0.167.. Test loss: 0.897.. Test accuracy: 0.803
# 284) Epoch 3/3.. Train loss: 0.165.. Test loss: 0.884.. Test accuracy: 0.807
# 285) Epoch 3/3.. Train loss: 0.173.. Test loss: 0.875.. Test accuracy: 0.794
# 286) Epoch 3/3.. Train loss: 0.157.. Test loss: 0.863.. Test accuracy: 0.790
# 287) Epoch 3/3.. Train loss: 0.165.. Test loss: 0.866.. Test accuracy: 0.792
# 288) Epoch 3/3.. Train loss: 0.170.. Test loss: 0.877.. Test accuracy: 0.782
# 289) Epoch 3/3.. Train loss: 0.166.. Test loss: 0.872.. Test accuracy: 0.780
# 290) Epoch 3/3.. Train loss: 0.174.. Test loss: 0.873.. Test accuracy: 0.779
# 291) Epoch 3/3.. Train loss: 0.132.. Test loss: 0.887.. Test accuracy: 0.771
# 292) Epoch 3/3.. Train loss: 0.162.. Test loss: 0.895.. Test accuracy: 0.764
# 293) Epoch 3/3.. Train loss: 0.192.. Test loss: 0.898.. Test accuracy: 0.770
# 294) Epoch 3/3.. Train loss: 0.194.. Test loss: 0.894.. Test accuracy: 0.774
# 295) Epoch 3/3.. Train loss: 0.180.. Test loss: 0.887.. Test accuracy: 0.783
# 296) Epoch 3/3.. Train loss: 0.145.. Test loss: 0.878.. Test accuracy: 0.779
# 297) Epoch 3/3.. Train loss: 0.159.. Test loss: 0.886.. Test accuracy: 0.773
# 298) Epoch 3/3.. Train loss: 0.165.. Test loss: 0.878.. Test accuracy: 0.775
# 299) Epoch 3/3.. Train loss: 0.167.. Test loss: 0.874.. Test accuracy: 0.778
# 300) Epoch 3/3.. Train loss: 0.141.. Test loss: 0.863.. Test accuracy: 0.786
# 301) Epoch 3/3.. Train loss: 0.174.. Test loss: 0.844.. Test accuracy: 0.793
# 302) Epoch 3/3.. Train loss: 0.138.. Test loss: 0.833.. Test accuracy: 0.803
# 303) Epoch 3/3.. Train loss: 0.169.. Test loss: 0.831.. Test accuracy: 0.800
# 304) Epoch 3/3.. Train loss: 0.146.. Test loss: 0.827.. Test accuracy: 0.806
# 305) Epoch 3/3.. Train loss: 0.176.. Test loss: 0.826.. Test accuracy: 0.801
# 306) Epoch 3/3.. Train loss: 0.166.. Test loss: 0.831.. Test accuracy: 0.794
# 307) Epoch 3/3.. Train loss: 0.171.. Test loss: 0.825.. Test accuracy: 0.796
# 308) Epoch 3/3.. Train loss: 0.209.. Test loss: 0.825.. Test accuracy: 0.799
# 309) Epoch 3/3.. Train loss: 0.160.. Test loss: 0.833.. Test accuracy: 0.790

# %%
print(control_dict[1])
print(len(control_dict))
train_data = np.array(list(control_dict.values()))
print(train_data[0])
# Out:
# [0.47127742767333985, 4.653341733492338, 0.013221153846153846]
# 309
# [ 0.47127743  4.65334173  0.01322115]

# %%
# %matplotlib inline
x_ax = np.arange(len(control_dict))*0.01
y_trl = train_data[:,0]*10
y_tesl = train_data[:,1]
y_acc = train_data[:,2]*10
plt.plot(x_ax, y_trl, label = 'train loss')
plt.plot(x_ax, y_tesl, label = 'test loss')
plt.plot(x_ax, y_acc, label = 'accuracy')
plt.title('Training data')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
loss = 0
accuracy = 0
model.to(device)
model.eval()
with torch.no_grad():
    for inputs2, labels2 in testloader:
        inputs2, labels2 = inputs2.to(device), labels2.to(device)
        test_logps = model.forward(inputs2)
        test_ps = torch.exp(test_logps)
        top_p, top_class = test_ps.topk(1, dim=1)
        equals = top_class == labels2.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

print('Test set accuracy: %d %%' % (100 * accuracy / len(testloader)))
# Out:
# Test set accuracy: 78 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_dataset.class_to_idx

print("Model's state_dict:")
for param_tensor in model.fc.state_dict():
    print(param_tensor, "\t", model.fc.state_dict()[param_tensor].size())
for var_name in optimizer.state_dict():
    print(var_name, "\t", optimizer.state_dict()[var_name])
    
checkpoint = OrderedDict([('epochs', epochs),
                          ('model', model.state_dict()),
                          ('classifier', classifier),
                          ('optimizer', optimizer.state_dict()),
                          ('loss', criterion),
                          ('learning_rate', 0.002),
                          ('class_to_idx', model.class_to_idx),
                          ('pretrained_model', 'resnet18')])
torch.save(checkpoint, 'resnet18.pth')
# Out:
# Model's state_dict:
# inp.weight 	 torch.Size([256, 512])
# inp.bias 	 torch.Size([256])
# out.weight 	 torch.Size([102, 256])
# out.bias 	 torch.Size([102])
# state 	 {139838974880648: {'step': 309, 'exp_avg': tensor(1.00000e-02 *
#        [[ 0.0000,  0.0000, -0.0000,  ..., -0.0000,  0.0000,  0.0000],
#         [-0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000, -0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [-0.0000,  0.0000, -0.0000,  ..., -0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000, -0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]], device='cuda:0'), 'exp_avg_sq': tensor(1.00000e-05 *
#        [[ 0.0054,  0.0021,  0.0002,  ...,  0.0021,  0.0028,  0.0026],
#         [ 0.0008,  0.0002,  0.0004,  ...,  0.0001,  0.0002,  0.0000],
#         [ 0.0034,  0.0030,  0.0053,  ...,  0.0059,  0.0006,  0.0041],
#         ...,
#         [ 0.0214,  0.0185,  0.0215,  ...,  0.0176,  0.0232,  0.0349],
#         [ 0.0006,  0.0022,  0.0010,  ...,  0.0008,  0.0038,  0.0051],
#         [ 0.0016,  0.0011,  0.0014,  ...,  0.0001,  0.0004,  0.0028]], device='cuda:0')}, 139838974877984: {'step': 309, 'exp_avg': tensor(1.00000e-03 *
#        [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000, -0.1877,  2.3632,
#          0.0000,  0.0000, -0.3068, -3.9667,  0.0000,  1.6813,  1.8247,
#          0.0000, -1.2591,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.6465,  0.0000,  0.0000,  1.9369, -2.0791,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0389,  0.0000,  0.0000, -3.4344,
#          0.0000, -2.7279,  0.0000,  0.0000,  0.0000,  2.8145,  1.9832,
#          0.0000,  0.0000,  0.0000, -2.9401,  0.0000,  0.0000,  1.2642,
#          0.0000,  1.8667,  0.0000, -1.6053,  0.0000, -1.7956,  0.0000,
#          0.0000,  0.0000,  0.0000, -1.3725,  1.4804, -2.4609,  3.2289,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  1.0513,
#          1.8646,  0.0000,  0.0000,  0.0000,  0.0000,  0.4060, -0.2840,
#          0.0000,  0.0000,  0.0000,  1.1252,  0.0000,  0.0000,  0.0000,
#          2.1864,  0.6986,  0.0000,  0.0000,  0.0000,  0.0000, -0.1560,
#          0.0000, -3.0011,  0.0000,  4.0360,  2.6760,  0.4502,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  2.5804, -0.3756, -0.7665,
#          0.0000,  0.8081,  0.2479,  0.0000,  0.0000,  0.0209, -0.1034,
#         -3.2077,  0.0532,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          3.3807, -1.9588,  0.0000,  0.0000, -2.1142,  0.0000,  5.1626,
#          0.0000,  2.3544,  3.2142,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  1.6699,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  1.3868,  0.9911,  0.0000,  3.2772,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  2.0832,  2.2372,  0.0000,
#          1.1041, -1.6612,  0.0000,  0.0000, -4.1251,  0.0000,  0.8641,
#          3.2853,  0.0000,  0.0000,  0.0000, -1.4280,  0.0000,  1.5371,
#         -1.3428,  0.0000,  0.0000,  1.9405,  0.0000,  0.0000, -3.0069,
#         -0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.8201,  0.0000,
#         -3.2803,  0.0000,  4.0252,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  1.7583,  0.0000,  0.0000, -0.0010,  0.0000,  0.0000,
#          0.0000,  5.3371,  0.3799, -1.3090, -1.9340,  0.0000, -2.6662,
#          0.0882,  0.0000,  0.0000,  0.0000,  0.8948, -1.9019,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000, -1.3760,  2.0768,  6.9296,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#         -0.1917,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000, -0.6259,
#          1.1051,  2.3288, -0.3625,  0.0000,  0.0000,  0.0000,  0.0215,
#          0.0000,  0.0000,  0.0000,  0.0000, -0.5220, -0.3976,  0.0000,
#          0.0000, -1.3659,  1.4799,  1.1737, -0.7416, -0.4337, -3.7161,
#          0.0000,  0.0000,  0.0000,  0.0000], device='cuda:0'), 'exp_avg_sq': tensor(1.00000e-05 *
#        [ 0.0012,  0.0001,  0.0027,  0.0006,  0.0029,  1.2719,  1.7817,
#          0.0026,  0.0089,  2.0358,  1.5576,  0.0018,  1.3170,  1.5986,
#          0.0043,  1.4997,  0.0356,  0.0204,  0.0353,  0.0020,  0.0000,
#          0.9374,  0.0000,  0.0630,  1.7385,  1.5286,  0.0107,  0.0003,
#          0.0043,  0.0221,  0.0168,  1.4018,  0.0103,  0.0565,  1.9117,
#          0.0037,  1.5723,  0.0019,  0.0123,  0.0024,  1.7216,  2.1363,
#          0.0021,  0.0038,  0.0244,  1.6659,  0.0031,  0.0012,  1.5593,
#          0.0108,  1.3738,  0.0014,  1.5966,  0.0198,  1.2949,  0.0005,
#          0.0131,  0.0001,  0.0023,  1.6709,  2.1329,  1.3919,  2.6690,
#          0.0007,  0.0000,  0.0002,  0.0093,  0.0037,  0.0019,  1.4569,
#          1.5442,  0.0056,  0.0001,  0.0007,  0.0020,  1.3898,  1.9417,
#          0.0056,  0.0359,  0.0014,  2.3593,  0.0037,  0.0338,  0.0008,
#          1.8658,  1.4995,  0.0001,  0.0034,  0.0033,  0.0024,  1.5246,
#          0.0630,  2.1320,  0.0059,  1.2343,  1.5240,  0.9310,  0.0075,
#          0.0104,  0.0006,  0.0023,  0.0070,  1.7856,  1.4855,  1.2305,
#          0.0002,  1.1796,  1.3757,  0.0450,  0.0015,  2.2378,  1.8021,
#          1.7334,  1.5876,  0.0107,  0.0007,  0.0029,  0.0025,  0.0026,
#          1.5372,  2.0905,  0.0004,  0.0000,  1.8187,  0.0016,  1.8813,
#          0.0018,  1.4669,  1.4185,  0.0095,  0.0064,  0.0453,  0.0110,
#          0.0006,  0.0150,  0.0635,  1.4530,  0.0421,  0.0034,  0.0017,
#          0.0000,  0.0011,  1.3847,  2.0153,  0.0044,  1.3316,  0.0082,
#          0.0002,  0.0010,  0.0000,  0.0009,  1.2480,  1.7144,  0.0008,
#          1.5797,  1.8197,  0.0109,  0.0254,  1.5773,  0.0001,  2.3819,
#          1.7828,  0.0008,  0.0010,  0.0007,  1.3178,  0.0018,  1.4204,
#          1.5707,  0.0039,  0.0002,  1.5349,  0.0007,  0.0141,  1.4566,
#          0.0740,  0.0000,  0.0034,  0.0064,  0.0001,  1.4572,  0.0003,
#          1.5002,  0.0001,  1.5413,  0.0000,  0.0060,  0.0073,  0.0046,
#          0.0000,  1.3113,  0.0217,  0.0001,  1.7214,  0.0144,  0.0001,
#          0.0046,  1.9426,  1.2047,  1.3067,  1.8359,  0.0397,  1.2689,
#          1.7931,  0.0010,  0.0228,  0.0047,  1.7865,  1.4307,  0.0063,
#          0.0329,  0.0485,  0.0040,  0.0004,  1.4125,  1.4809,  1.8720,
#          0.0163,  0.0004,  0.0070,  0.0010,  0.0277,  0.0110,  0.0207,
#          1.5043,  0.0001,  0.0311,  0.0033,  0.0008,  0.0026,  2.7318,
#          1.7325,  1.5602,  1.3654,  0.0140,  0.0346,  0.0072,  1.6201,
#          0.0395,  0.0048,  0.0008,  0.0023,  1.2350,  2.0364,  0.0044,
#          0.0120,  1.8570,  1.6530,  1.6480,  1.8378,  1.4579,  1.4663,
#          0.0075,  0.0187,  0.0015,  0.0016], device='cuda:0')}, 139837552518920: {'step': 309, 'exp_avg': tensor(1.00000e-02 *
#        [[ 0.0000,  0.0000, -0.0000,  ..., -0.0000, -0.0000, -0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0000,  0.0000,  0.0000],
#         [-0.0000, -0.0000,  0.0000,  ...,  0.0000,  0.0000, -0.0000],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000, -0.0000,  ...,  0.0000, -0.0000, -0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]], device='cuda:0'), 'exp_avg_sq': tensor(1.00000e-03 *
#        [[ 0.0000,  0.0000,  0.0000,  ...,  0.0013,  0.0002,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0008,  0.0000,  0.0000],
#         [ 0.0003,  0.0001,  0.0000,  ...,  0.0001,  0.0000,  0.0005],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0011,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0001,  ...,  0.0014,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0027,  0.0000,  0.0000]], device='cuda:0')}, 139837552518632: {'step': 309, 'exp_avg': tensor(1.00000e-03 *
#        [ 0.0974, -2.4773, -0.0700,  2.9807, -0.3251, -0.0039,  1.4535,
#          2.8372,  1.6417, -1.0806,  0.8412, -0.9050,  4.2460, -3.4799,
#         -4.6526,  0.9431, -1.2346,  0.8003, -0.4416, -1.3012, -3.1619,
#          2.1708,  2.0387, -2.9933, -1.8806, -1.5188,  3.9869,  4.2839,
#          2.2695,  2.2281, -1.2839,  0.5567, -0.1006,  2.9615,  1.7281,
#         -3.9175,  1.4979,  1.0225,  0.3870,  1.9160, -6.2148,  2.8182,
#          0.8265, -0.3757,  0.5601,  2.7134, -4.4205, -2.1935,  0.1593,
#          3.0312,  1.1285, -1.0213, -0.5513,  2.4461, -2.7638, -2.6879,
#         -0.8254, -0.5941, -0.5599,  1.1637,  1.7020, -2.5740,  1.2870,
#         -3.3263, -3.3012,  1.6618,  0.5924,  2.3045,  1.3204, -0.8775,
#          2.8762,  0.4105, -1.5857, -4.7849, -6.9674, -0.7791, -4.3615,
#         -2.4831, -4.0677,  0.0617, -3.1450,  4.7253,  0.0045,  1.9393,
#          1.2431, -0.0740, -4.5308,  4.0569,  3.1180, -0.1534,  9.8164,
#         -0.6080, -0.3270,  2.2701,  2.9142, -3.3292,  2.0010, -1.0929,
#         -2.6590,  1.6769, -1.1671,  1.5138], device='cuda:0'), 'exp_avg_sq': tensor(1.00000e-04 *
#        [ 0.1816,  0.2192,  0.2161,  0.3169,  0.1584,  0.3888,  0.3305,
#          0.2342,  0.2794,  0.3057,  0.2395,  0.2739,  0.4567,  0.2891,
#          0.2408,  0.2625,  0.2141,  0.2997,  0.2888,  0.2051,  0.1709,
#          0.1693,  0.1830,  0.3251,  0.3622,  0.2574,  0.3608,  0.3554,
#          0.2559,  0.1831,  0.1550,  0.2082,  0.3288,  0.3172,  0.2592,
#          0.2330,  0.3004,  0.3347,  0.4768,  0.3136,  0.7107,  0.3103,
#          0.2406,  0.7022,  0.1674,  0.3078,  0.2198,  0.3630,  0.4106,
#          1.2636,  0.3224,  0.4913,  0.1849,  0.3926,  0.3824,  0.3168,
#          0.2517,  0.3514,  0.1595,  0.2874,  0.2309,  0.2717,  0.1781,
#          0.1970,  0.4705,  0.2341,  0.2761,  0.2642,  0.2341,  0.2058,
#          0.2651,  0.3107,  0.6394,  0.7777,  0.9270,  0.5816,  0.5298,
#          0.8304,  0.6989,  0.1826,  0.2805,  0.5075,  0.5811,  0.5292,
#          0.6768,  0.5649,  0.2623,  0.2811,  0.3108,  0.7479,  1.0653,
#          0.2633,  0.3998,  0.3932,  0.3104,  0.2505,  0.6861,  0.5714,
#          0.4904,  0.3806,  0.4452,  0.3179], device='cuda:0')}}
# param_groups 	 [{'lr': 0.002, 'betas': (0.9, 0.999), 'eps': 1e-08, 'weight_decay': 0, 'amsgrad': False, 'params': [139838974880648, 139838974877984, 139837552518920, 139837552518632]}]

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def loading_model(path):
    checkpoint = torch.load(path)
    model = models.resnet18(pretrained=True)
    model.fc = checkpoint['classifier']
    learning_rate = checkpoint['learning_rate']
    model.epochs = checkpoint['epochs']
    model.optimizer = checkpoint['optimizer']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['model'])
    criterion = checkpoint['loss']
    
    return model

model_trained = loading_model('resnet18.pth')
print(model_trained)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 100%|██████████| 46827520/46827520 [00:00<00:00, 62367935.96it/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Sequential(
#     (inp): Linear(in_features=512, out_features=256, bias=True)
#     (dropout): Dropout(p=0.4)
#     (relu): ReLU()
#     (out): Linear(in_features=256, out_features=102, bias=True)
#     (softmax): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    w,h = image.size
    if w > h:
        image.thumbnail((w,256),Image.ANTIALIAS)
    else:
        image.thumbnail((256,h),Image.ANTIALIAS)
    
    coords = ((256 - 224)/2,(256 + 224)/2,(256 - 224)/2,(256 + 224)/2)
    (u,d,l,r) = coords
    im_crop = image.crop((u,l,d,r))
    means = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_im = np.array(im_crop)
    np_im = np_im/255
    im_normalized = np.array((np_im-means)/std)
    return np.transpose(im_normalized, (2,0,1))

# %%
#To reviewer: Why using PIL? Pytorch seems to be a better solution...
def process_image_PyTorch(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    resizing = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
    result = resizing(image)
    return np.array(result)
    # TODO: Process a PIL image for use in a PyTorch model

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

img_path = 'flowers/test/2/image_05107.jpg'
im_path2 = 'flowers/test/88/image_00540.jpg'
with Image.open(img_path) as image: # original
    plt.imshow(image)
    
with Image.open(img_path) as image: #processed with functions
    imshow(process_image(image))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    img_open = Image.open(image_path) 
    img_processed = process_image_PyTorch(img_open)
    img_torch = torch.from_numpy(img_processed)
    
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    if device == torch.device('cuda'):
        with torch.no_grad():
            output = model.forward(img_torch.cuda())
    else: 
        with torch.no_grad():
            output = model.forward(img_torch)
        
    probability = F.softmax(output.data,dim=1)
    
    probs = np.array(probability.topk(topk)[0][0])
    
    index_to_class = {val: key for key, val in model.class_to_idx.items()}
    top_classes = [np.int(index_to_class[each]) for each in np.array(probability.topk(topk)[1][0])]
    
    return probs, top_classes
    # TODO: Implement the code to predict the class from an image file

# %%
model_pred = loading_model('resnet18.pth')

# %%
img = ('flowers/test/1/image_06743.jpg')
probs, classes = predict(img, model_pred)
print(probs)
print(classes)
# Out:
# [ 0.51894993  0.29300362  0.09522747  0.03708038  0.00855501]
# [1, 51, 83, 86, 52]

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
plt.figure(figsize=(3,3))
 
path = ('flowers/test/88/image_00540.jpg')
image = process_image_PyTorch(Image.open(path))    
probs, classes = predict(path, model_pred)
max_index = classes[0]
    
axs = imshow(image, ax = plt)
axs.axis('off')
axs.title(cat_to_name[str(max_index)])
axs.show()

plt.subplot(121)

names = [cat_to_name[str(index)] for index in classes]
y_pos = np.arange(len(names))
performance = np.array(probs)

plt.barh(y_pos, performance, align='center',
        color='blue')
plt.yticks(y_pos, names)
plt.gca().invert_yaxis()
